# %% [markdown]
# # LetsGrowMore- Virtual Internship Program (VIP)- Data Science
#
# Author : *Ketan Singh*
#
# Task 3 :- Image to Pencil Sketch with Python
#
# Import required libraries

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Importing Image**

# %%
image = cv2.imread("/content/naru sasu.jpg")
cv2_imshow(image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Converting the original image to greyscale**

# %%
grey_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F1B5639AA90>

# %% [markdown]
# **Inverting the greyscale image**

# %%
inverted_image = 255 - grey_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F1B563AAA50>

# %% [markdown]
# **Blurring the image by using the Gaussian Function**

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F1B5639A9D0>

# %% [markdown]
# **Pencil sketch**

# %%
def pencil_sketch(a, b):
  return cv2.divide(a, 255 - b, scale=256)
pencil_sketch=pencil_sketch(grey_image,blurred)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F1B563B1910>

# %% [markdown]
# **Original image and pencil sketch**

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
